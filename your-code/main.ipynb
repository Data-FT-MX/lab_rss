# %% [markdown]
# # Working with RSS Feeds Lab
#
# Complete the following set of exercises to solidify your knowledge of parsing RSS feeds and extracting information from them.

# %%
import feedparser

# %% [markdown]
# ### 1. Use feedparser to parse the following RSS feed URL.

# %%
url = 'http://feeds.feedburner.com/oreilly/radar/atom'

# %%
feeds = feedparser.parse(url)

# %% [markdown]
# ### 2. Obtain a list of components (keys) that are available for this feed.

# %%
feeds.keys()
# Out:
# dict_keys(['bozo', 'entries', 'feed', 'headers', 'etag', 'updated', 'updated_parsed', 'href', 'status', 'encoding', 'version', 'namespaces'])

# %% [markdown]
# ### 3. Obtain a list of components (keys) that are available for the *feed* component of this RSS feed.

# %%
feeds.feed.keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'subtitle', 'subtitle_detail', 'updated', 'updated_parsed', 'language', 'sy_updateperiod', 'sy_updatefrequency', 'generator_detail', 'generator', 'feedburner_info', 'geo_lat', 'geo_long', 'feedburner_emailserviceid', 'feedburner_feedburnerhostname'])

# %% [markdown]
# ### 4. Extract and print the feed title, subtitle, author, and link.

# %%
print(feeds.feed.title)
print("")
print(feeds.feed.subtitle)
print("")
print(feeds.feed.feedburner_emailserviceid.split("/")[2])
print("")
print(feeds.feed.link)
print("")
# Out:
# Radar
#
# Now, next, and beyond: Tracking need-to-know trends at the intersection of business and technology
#
# atom
#
# https://www.oreilly.com/radar

# %% [markdown]
# ### 5. Count the number of entries that are contained in this RSS feed.

# %%
len(feeds.entries)
# Out:
# 60

# %% [markdown]
# ### 6. Obtain a list of components (keys) available for an entry.
#
# *Hint: Remember to index first before requesting the keys*

# %%
feeds.entries[0].keys()
# Out:
# dict_keys(['title', 'title_detail', 'links', 'link', 'comments', 'published', 'published_parsed', 'authors', 'author', 'author_detail', 'tags', 'id', 'guidislink', 'summary', 'summary_detail', 'content', 'wfw_commentrss', 'slash_comments', 'feedburner_origlink'])

# %% [markdown]
# ### 7. Extract a list of entry titles.

# %%
titles=[feeds.entries[i].title for i in range(len(feeds.entries))]
titles
# Out:
# ['Radar trends to watch: September 2021',
#  'Rebranding Data',
#  'A Way Forward with Communal Computing',
#  'Defending against ransomware is all about the basics',
#  'Radar trends to watch: August 2021',
#  'Communal Computing’s Many Problems',
#  'Thinking About Glue',
#  'Radar trends to watch: July 2021',
#  'Hand Labeling Considered Harmful',
#  'Two economies. Two sets of rules.',
#  'Communal Computing',
#  'Code as Infrastructure',
#  'Radar trends to watch: June 2021',
#  'AI Powered Misinformation and Manipulation at Scale #GPT-3',
#  'DeepCheapFakes',
#  'Radar trends to watch: May 2021',
#  'Checking Jeff Bezos’s Math',
#  'AI Adoption in the Enterprise 2021',
#  'NFTs: Owning Digital Art',
#  'Radar trends to watch: April 2021',
#  'InfoTribes, Reality Brokers',
#  'The End of Silicon Valley as We Know It?',
#  'The Next Generation of AI',
#  'Radar trends to watch: March 2021',
#  'Product Management for AI',
#  '5 things on our data and AI radar for 2021',
# ...

# %% [markdown]
# ### 8. Calculate the percentage of "Four short links" entry titles.

# %%
fsltitles=[titles[i] for i in range(len(titles)) if titles[i].startswith("Four short links")]
print('The percentage of "Four short links" entry titles is',
      str(round((len(fsltitles)/len(titles))*100,2))+'%')
# Out:
# The percentage of "Four short links" entry titles is 28.33%

# %% [markdown]
# ### 9. Create a Pandas data frame from the feed's entries.

# %%
import pandas as pd

# %%
df = pd.DataFrame(feeds.entries)
df.head(2)
# Out:
#                                    title  \
# 0  Radar trends to watch: September 2021
# 1                        Rebranding Data
#
#                                         title_detail  \
# 0  {'type': 'text/plain', 'language': None, 'base...
# 1  {'type': 'text/plain', 'language': None, 'base...
#
#                                                links  \
# 0  [{'rel': 'alternate', 'type': 'text/html', 'hr...
# 1  [{'rel': 'alternate', 'type': 'text/html', 'hr...
#
#                                                 link  \
# 0  http://feedproxy.google.com/~r/oreilly/radar/a...
# 1  http://feedproxy.google.com/~r/oreilly/radar/a...
#
#                                             comments  \
# 0  https://www.oreilly.com/radar/radar-trends-to-...
# 1  https://www.oreilly.com/radar/rebranding-data/...
#
#                          published                      published_parsed  \
# 0  Wed, 01 Sep 2021 12:18:33 +0000   (2021, 9, 1, 12, 18, 33, 2, 244, 0)
# ...

# %% [markdown]
# ### 10. Count the number of entries per author and sort them in descending order.

# %%
df.groupby(['author']).size().sort_values(ascending=False)
# Out:
# author
# Mike Loukides                               25
# Nat Torkington                              17
#                                              4
# Chris Butler                                 3
# Tim O’Reilly                                 3
# Hugo Bowne-Anderson                          1
# Justin Norman and Mike Loukides              1
# Kevlin Henney                                1
# Nitesh Dhanjani                              1
# Patrick Hall and Ayoub Ouederni              1
# Q McCallum                                   1
# Q McCallum, Shane Glynn and Chris Butler     1
# Shayan Mohanty and Hugo Bowne-Anderson       1
# dtype: int64

# %% [markdown]
# ### 11. Add a new column to the data frame that contains the length (number of characters) of each entry title. Return a data frame that contains the title, author, and title length of each entry in descending order (longest title length at the top).

# %%
length=[len(i) for i in df['title']]
df['length']=length
df[['title','author','length']].sort_values(by=['length'],ascending=False)
# Out:
#                                                 title  \
# 29  Where Programming, Ops, AI, and the Cloud are ...
# 13  AI Powered Misinformation and Manipulation at ...
# 26  5 infrastructure and operations trends to watc...
# 35  O’Reilly’s top 20 live online training courses...
# 3   Defending against ransomware is all about the ...
# 25         5 things on our data and AI radar for 2021
# 30          Seven Legal Questions for Data Scientists
# 21           The End of Silicon Valley as We Know It?
# 57             AI Product Management After Deployment
# 0               Radar trends to watch: September 2021
# 2               A Way Forward with Communal Computing
# 50               Radar trends to watch: November 2020
# 39               Radar trends to watch: December 2020
# 28               Radar trends to watch: February 2021
# 32                Radar trends to watch: January 2021
# 47                 Four short links: 10 November 2020
# ...

# %% [markdown]
# ### 12. Create a list of entry titles whose summary includes the phrase "machine learning."

# %%
[i for i in df['title'] if "machine learning" in i.lower()]
# Out:
# []
